# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input

# %%
from dataset import Dataset
from model import Yolo

# %%
data_dir = '/home/b00077985/workspace/datasets/coco'
coco = Dataset(data_dir, 'train2014')
# Out:
# loading annotations into memory...
# Done (t=8.48s)
# creating index...
# index created!

# %%
IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13

BOX              = 5

OBJ_THRESHOLD    = 0.5
NMS_THRESHOLD    = 0.45
ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]

# %%
batch_generator = coco.generator(box=BOX)

# %%
LABELS           = coco.get_labels()
CLASS_WEIGHTS    = np.ones(len(LABELS), dtype='float32')

OBJECT_SCALE     = 5.0
NO_OBJECT_SCALE  = 1.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 1.0

TRUE_BOX_BUFFER  = 50

WARM_UP_BATCHES  = 0
BATCH_SIZE       = 16

# %%
yolo = Yolo(input_shape=(IMAGE_H, IMAGE_W, 3), labels=LABELS, grid=(GRID_H, GRID_W), anchors=ANCHORS, boxes=BOX)

# %%
yolo.compile()

# %%
yolo.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 416, 416, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 416, 416, 32) 128         conv_1[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 416, 416, 32) 0           norm_1[2][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 208, 208, 32) 0           leaky_re_lu[2][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 208, 208, 64) 18432       max_pooling2d[2][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 208, 208, 64) 256         conv_2[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 208, 208, 64) 0           norm_2[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 104, 104, 64) 0           leaky_re_lu_1[2][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 104, 104, 128 73728       max_pooling2d_1[2][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 104, 104, 128 512         conv_3[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 104, 104, 128 0           norm_3[2][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 104, 104, 64) 8192        leaky_re_lu_2[2][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 104, 104, 64) 256         conv_4[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 104, 104, 64) 0           norm_4[2][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 104, 104, 128 73728       leaky_re_lu_3[2][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 104, 104, 128 512         conv_5[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 104, 104, 128 0           norm_5[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 128)  0           leaky_re_lu_4[2][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 52, 52, 256)  294912      max_pooling2d_2[2][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 52, 52, 256)  1024        conv_6[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 52, 52, 256)  0           norm_6[2][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 52, 52, 128)  32768       leaky_re_lu_5[2][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 52, 52, 128)  512         conv_7[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 52, 52, 128)  0           norm_7[2][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 52, 52, 256)  294912      leaky_re_lu_6[2][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 52, 52, 256)  1024        conv_8[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 52, 52, 256)  0           norm_8[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 256)  0           leaky_re_lu_7[2][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 26, 26, 512)  1179648     max_pooling2d_3[2][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 26, 26, 512)  2048        conv_9[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 26, 26, 512)  0           norm_9[2][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 26, 26, 256)  131072      leaky_re_lu_8[2][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 26, 26, 256)  1024        conv_10[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 26, 26, 256)  0           norm_10[2][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_re_lu_9[2][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_11[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 26, 26, 512)  0           norm_11[2][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 26, 26, 256)  131072      leaky_re_lu_10[2][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 26, 26, 256)  1024        conv_12[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 26, 26, 256)  0           norm_12[2][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_re_lu_11[2][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_13[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 26, 26, 512)  0           norm_13[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 13, 13, 512)  0           leaky_re_lu_12[2][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 13, 13, 1024) 4718592     max_pooling2d_4[2][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_14[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_14[2][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 13, 13, 512)  524288      leaky_re_lu_13[2][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 13, 13, 512)  2048        conv_15[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 13, 13, 512)  0           norm_15[2][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_re_lu_14[2][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_16[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_16[2][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 13, 13, 512)  524288      leaky_re_lu_15[2][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 13, 13, 512)  2048        conv_17[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 13, 13, 512)  0           norm_17[2][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_re_lu_16[2][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_18[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_18[2][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 13, 13, 1024) 9437184     leaky_re_lu_17[2][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_19[2][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 26, 26, 512)  262144      leaky_re_lu_12[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_19[2][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_21[2][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 13, 13, 1024) 9437184     leaky_re_lu_18[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 26, 26, 512)  0           norm_21[2][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_20[2][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 13, 13, 2048) 0           leaky_re_lu_20[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_20[2][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 13, 13, 3072) 0           lambda[2][0]
#                                                                  leaky_re_lu_19[2][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 13, 13, 1024) 28311552    concatenate_2[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_22[2][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_22[2][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 13, 13, 425)  435625      leaky_re_lu_21[2][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1, 1, 1, 50, 0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 13, 13, 5, 85 0           conv_23[2][0]
# ==================================================================================================
# Total params: 67,729,801
# Trainable params: 67,708,233
# Non-trainable params: 21,568
# __________________________________________________________________________________________________

# %%
yolo.fit_generator(generator=

# %%
weights_path = 'weights'                      
train_image_folder = 'dataset/'
train_annot_folder = 'dataset/'

# %%
generator_config = {
    'IMAGE_H'         : IMAGE_H,
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : TRUE_BOX_BUFFER,
}

# %%
optimizer = Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(loss=custom_loss, optimizer=optimizer)

# %%
train_batch = BatchGenerator(train_imgs, generator_config, norm=normalize)

# %%
model.fit_generator(generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 100, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [early_stop, checkpoint], 
                    max_queue_size   = 3)
